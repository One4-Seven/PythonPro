# %% [markdown]
# ### 页面动态加载数据的爬取 Selenium
# - 借助Selenium库和浏览器驱动程序实现
# ### 基本步骤
# - 创建浏览器对象
# - 选择指定的HTML文本对象
# - 执行输入和查询操作
# - 将搜索结果保存本地
# #### 以百度为例用自动化脚本实现爬取指定信息

# %%
from selenium.webdriver.common.by import By
from selenium import webdriver
from time import sleep

url = 'https://www.baidu.com/'

browser = webdriver.Edge()  # 创建浏览器对象 #
sleep(1)

browser.get(url)  # 前往指定网址 #
search_box = browser.find_element(By.ID, 'kw')  # 定位网页中id为kw的元素，即百度搜索输入框
search_box.clear()  # 清空输入框
sleep(1)

search_box.send_keys('美少女战士')
sleep(1)

browser.find_element(By.ID, 'su').click()  # 按下回车键
sleep(1)

content = browser.find_element(By.ID, 'content_left').text  # 获取页面内容 #
print(content.split())

browser.quit()  # 关闭浏览器 #
# Out:
# ['美少女战士', '-', '百度百科', '\ue66a', '《美少女战士》是一部由东映动画制作，该片由佐藤顺一、几原邦彦等导演，富田佑弘、榎户洋司等编，三石琴乃、久川绫、富泽美智惠、筱原惠美等配音的魔法少女变身类动画片。《美少女战士》故事根据漫画家武内直子的同名原著改编，描绘了主人公月野兔在某一天意...详情\ue734', '剧情简介', '角色介绍', '战士名单', '动画制作', '百度百科', '美少女战士-高清视频在线观看', '\ue627', '已完结全46集', '2003-10-04日本', '类型：动作科幻冒险', '百科：月野兔(沢井美优', '饰)是一位个性活泼开朗,热情善良,内心里充满了正义感的初中生。一次偶然中,她遇见了一只名叫露娜的黑猫,让月野兔感到不可思议的时,露娜竟然会说人类的语言。露娜告...', '更多', '>', '爱奇艺', '1集', '2集', '3集', '4集', '5集', '6集', '7集', '8集', '9集', '10集', '11集', '12集', '13集', '14集', '15集', '16集', '显示全部《美少女战士》视频\ue615', '搜索智能精选\ue62b', '系列作品', '全26集', '美少女战士Crystal', '第六部', '全34集', '美少女战士之最后的星光', '第五部', '全39集', '美少女战士SuperS', '第四部', '更新至38集', '美少女战士S', '第三部', '\ue734', '美少女战士', '-', '百度图片', 'image.baidu.com\ue62b查看全部174,850', '张图片', '大家还在搜', '美少女战士官方正版手游美少女战士百度百科美少女战士永恒之章上免费美少女战士战斗力排名美少女战士真人版在线观看《战士第二季》在线观看', '美少女战士剧情介绍(49集全)_电视猫', '简介：', 'Sailor', 'Venus一开始冒充月亮公主，到最后才揭开真正的公主是Sailor', 'Moon。黑猫露娜会变身成小女孩的形象。至于地场卫，则成为了有女朋友的人。因此造成小兔的争风吃醋的情节。美奈子则成为了人气偶像歌手，而小玲也跃跃欲试，两人也...', '01-03集', '04-06集', '07-09集', '10-12集', '13-15集', '16-18集', '19-21集', '22-24集', '25-27集', '28-30集', '31-33集', '34-36集', '37-39集', '40-42集', '43-45集', '更多>>', 'www.tvmao.com', '2024-08-06\ue62b', '美少女战士R(日本1993年佐藤顺一执导动画)', '-', '百度百科', '\ue627', '类型：动画作品', '导演：佐藤顺一、几原邦彦', '简介：《美少女战士R》是续第一部《美少女战士》的续作。是1993年3月6日到1994年3月5日播放的日本动画作品，香港由无线电视...', '故事简介', '主要人物', 'Staff', 'CAST', '每集标题', '主题歌', '百度百科\ue62b', '《美少女战士第一季》免费在线观看_美少女战士第一季高清...', '2023年3月10日', '为了保卫地球,挫败黑暗帝国的野心,月野和水野亚美(久川绫', '配音)、火野丽(富泽美智惠', '配音)、木野真琴(篠原惠美', '配音)、爱野美奈子(深见梨加', '配音)等人结成美少女战士,与罪恶展开了...', 'www.tz-shengye.com/dongman/mei...\ue62b', '美少女战士人物介绍!', '2023年6月12日', '月野兔：系列的第一女主角，亦是美少女战士中的公主。她是一个冒失、爱哭、学业成绩差但重情义的14岁女生，但她拥有大爱、同情心及理解别人的能力，梦想是成为一个新娘。她前世是月...', '路小路说动漫\ue62b', '美少女战士27年前就告诉我们,不好惹的女孩长什么样!', '-', '知乎', '2019年6月1日', '与以往动漫作品的女性形象不同,主角不是要人保护的柔弱公主,而是5位不好惹的女战士,她们穿着水手服对抗邪恶。', '当年,不仅日本万人空巷,全球范围也兴起了一阵“美少女战士”热潮。', '中...', '知乎\ue62b', '美少女战士', '美少女戦士セーラームーン', '第1集', '爱哭鬼阿兔的...', '美少女战士', '美少女戦士セーラームーン第1集', '爱哭鬼阿兔的华丽变身', '全片播放', '本集中文名:爱哭鬼阿兔的华丽变身', '本集原名:泣き虫うさぎの華麗なる変身', '播放时间:1992-03-07星期...', '豆瓣电影\ue62b']
